# %%
import pandas as pd

# %%
# Задача 2
power = (pd.read_csv('C:\\Users\\Professional\\Desktop\\power.csv'))
power_dz = power[ ((power.country == 'Latvia') | (power.country == 'Lithuania') | (power.country == 'Estonia')) & ( (power.year >= 2005 ) & ( power.year <= 2010 ) & ( power.quantity > 0 )) & (( power.category == 4) | ( power.category == 12) | ( power.category == 21))]
sum(power_dz.quantity)
# Out:
# 240580.0

# %%
# Задача 3

page_url = 'https://www.medsoftpro.ru/kalkulyatory/ideal-weght'
rv = pd.read_html(page_url, attrs = {'class': 't_style table'}, encoding = 'utf-8')
rv[:6][0]
# Out:
#    Рост, cм 20–29 лет      30–39 лет      40–49 лет      50–59 лет       \
#    Рост, cм      муж. жен.      муж. жен.      муж. жен.      муж. жен.
# 0       148       508  484        55  523       566  547        56  532
# 1       150       513  489       567  539       581  565        58  557
# 2       152       513   51       587   55       615  595       611  576
# 3       154       553   53       616  591       645  624       638  602
# 4       156       585  558       644  615       673   66       658  624
# 5       158       612  581       673  641       704  679        68  645
# 6       160       629  598       692  658       723  699       697  658
# 7       162       646  616        71  685       744  727       727  687
# 8       164       673  636       739  708       772   74       756   72
# 9       166       688  652       745  718        78  765       763  738
# 10      168       708  685       763  737       796  782       779  748
# ...

# %%
# Задача 1
data = pd.read_csv('C:\\Users\\Professional\\Desktop\\ratings.csv')
data_5 = data[data.rating == 5.0]
dz_out = data_5.groupby('movieId').count().sort_values('rating', ascending=False).head(1)
dz_out
# Out:
#          userId  rating  timestamp
# movieId
# 318       48762   48762      48762
